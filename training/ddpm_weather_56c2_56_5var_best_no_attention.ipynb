# %% [markdown]
# ## Setup

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Requires TensorFlow >=2.11 for the GroupNormalization layer.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, ConvLSTM2D, BatchNormalization, Conv3D
from tensorflow.keras.callbacks import *

import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
tf.__version__
# Out:
# '2.11.0'

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 256
num_epochs = 800         # Just for the sake of demonstration
total_timesteps = 1000   # 1000
norm_groups = 8          # Number of groups used in GroupNormalization layer
learning_rate = 1e-4

img_size_H = 32
img_size_W = 64
img_channels = 5

first_conv_channels = 64
channel_multiplier = [1, 2, 4, 8]
widths = [first_conv_channels * mult for mult in channel_multiplier]
has_attention = [False, False, True, True]
num_res_blocks = 2  # Number of residual blocks

# %% [markdown]
# ## Dataset

# %%
resolution_folder = '56degree'
resolution = '5.625'  #1.40625, 2.8125, 5.625
var_num = '5'

train_data_tf = np.load("/home/scratch/ERA5/" + resolution_folder + "/merged_data/concat_2006_2015_" + resolution + "_" + var_num + "var.npy")
val_data_tf = np.load("/home/scratch/ERA5/" + resolution_folder + "/merged_data/concat_2016_2016_" + resolution + "_" + var_num + "var.npy")
test_data_tf = np.load("/home/scratch/ERA5/" + resolution_folder + "/merged_data/concat_2017_2018_" + resolution + "_" + var_num + "var.npy")

# %%
train_data_tf = train_data_tf.transpose((0, 2, 3, 1))
val_data_tf = val_data_tf.transpose((0, 2, 3, 1))
test_data_tf = test_data_tf.transpose((0, 2, 3, 1))

print(train_data_tf.shape, val_data_tf.shape, test_data_tf.shape)
# Out:
# (14608, 32, 64, 5) (1464, 32, 64, 5) (2920, 32, 64, 5)

# %% [markdown]
# ### Preprocessing
#
# In terms of preprocessing, we rescale the pixel values in the range `[-1.0, 1.0]`.
#
# This is in line with the range of the pixel values that
# was applied by the authors of the [DDPMs paper](https://arxiv.org/abs/2006.11239).

# %%
from utils.normalization import batch_norm

# %%
train_data_tf_norm = batch_norm(train_data_tf, train_data_tf.shape, batch_size=1460)

# %%
train_data_tf_norm_pred = train_data_tf_norm[2:]
train_data_tf_norm_past1 = train_data_tf_norm[:-2]
train_data_tf_norm_past2 = train_data_tf_norm[1:-1]


# print(train_data_tf_norm_pred.shape, train_data_tf_norm_past1.shape, train_data_tf_norm_past2.shape)

# %%
val_data_tf_norm = batch_norm(val_data_tf, val_data_tf.shape, batch_size=1460)

val_data_tf_norm_pred = val_data_tf_norm[2:]
val_data_tf_norm_past1 = val_data_tf_norm[:-2]
val_data_tf_norm_past2 = val_data_tf_norm[1:-1]


# print(val_data_tf_norm_pred.shape, val_data_tf_norm_past1.shape, val_data_tf_norm_past2.shape)

# %% [markdown]
# ## Gaussian diffusion utilities
#
# We define the **forward process** and the **reverse process** as a separate utility. Most of the code in this utility has been borrowed
# from the original implementation with some slight modifications.

# %%
from layers.diffusion import GaussianDiffusion

# %% [markdown]
# ## Network architecture
#
# U-Net, originally developed for semantic segmentation, is an architecture that is
# widely used for implementing diffusion models but with some slight modifications:
#
# 1. The network accepts two inputs: Image and time step
# 2. Self-attention between the convolution blocks once we reach a specific resolution
# 3. Group Normalization instead of weight normalization
#
# We implement most of the things as used in the original paper. We use the
# `swish` activation function throughout the network. We use the variance scaling
# kernel initializer.
#
# The only difference here is the number of groups used for the
# `GroupNormalization` layer. For the our dataset,
# we found that a value of `groups=8` produces better results
# compared to the default value of `groups=32`. Dropout is optional and should be
# used where chances of over fitting is high.

# %%
from tensorflow.keras.models import load_model

pretrained_encoder = load_model('../saved_models/encoder_cnn_56deg_5var.h5')
# pretrained_encoder = load_model('../saved_models/encoder_cnn_56c2_5var.h5')
pretrained_encoder.summary()
# Out:
# Model: "encoder_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 64, 5)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 64, 32)        672
#
#  conv2d_7 (Conv2D)           (None, 32, 64, 128)       16512
#
#  conv2d_8 (Conv2D)           (None, 32, 64, 256)       131328
#
#  bottleneck (Conv2D)         (None, 32, 64, 512)       524800
#
#  conv2d_9 (Conv2D)           (None, 32, 64, 256)       524544
#
#  conv2d_10 (Conv2D)          (None, 32, 64, 128)       131200
#
#  conv2d_11 (Conv2D)          (None, 32, 64, 5)         2565
#
# =================================================================
# Total params: 1,331,621
# Trainable params: 1,331,621
# Non-trainable params: 0
# _________________________________________________________________
# 2024-07-25 00:39:12.153574: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-25 00:39:12.398792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 73312 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:4f:00.0, compute capability: 8.0

# %%
# Extract the first 5 layers
first_five_layers = pretrained_encoder.layers[:5]

# Display the first four layers to confirm
for i, layer in enumerate(first_five_layers):
    print(f"Layer {i}: {layer}")

# Create a new model using these layers
# Get the input of the pre-trained model
input_layer = pretrained_encoder.input

# Get the output of the fourth layer
output_layer = first_five_layers[-1].output

# Create the new model
pretrained_encoder = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# Print the summary of the new model
pretrained_encoder.summary()
# Out:
# Layer 0: <keras.engine.input_layer.InputLayer object at 0x7f00acb536d0>
# Layer 1: <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00acb53520>
# Layer 2: <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00acb525c0>
# Layer 3: <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00acb507f0>
# Layer 4: <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00acb2ba30>
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 64, 5)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 64, 32)        672
#
#  conv2d_7 (Conv2D)           (None, 32, 64, 128)       16512
#
#  conv2d_8 (Conv2D)           (None, 32, 64, 256)       131328
#
#  bottleneck (Conv2D)         (None, 32, 64, 512)       524800
#
# =================================================================
# Total params: 673,312
# Trainable params: 673,312
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in pretrained_encoder.layers:
    layer.trainable = False

pretrained_encoder._name = 'encoder'

# %%
# Kernel initializer to use
def kernel_init(scale):
    scale = max(scale, 1e-10)
    return keras.initializers.VarianceScaling(
        scale, mode="fan_avg", distribution="uniform"
    )


class AttentionBlock(layers.Layer):
    """Applies self-attention.

    Args:
        units: Number of units in the dense layers
        groups: Number of groups to be used for GroupNormalization layer
    """

    def __init__(self, units, groups=8, **kwargs):
        self.units = units
        self.groups = groups
        super().__init__(**kwargs)

        self.norm = layers.GroupNormalization(groups=groups)
        self.query = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.key = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.value = layers.Dense(units, kernel_initializer=kernel_init(1.0))
        self.proj = layers.Dense(units, kernel_initializer=kernel_init(0.0))

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        height = tf.shape(inputs)[1]
        width = tf.shape(inputs)[2]
        scale = tf.cast(self.units, tf.float32) ** (-0.5)

        inputs = self.norm(inputs)
        q = self.query(inputs)
        k = self.key(inputs)
        v = self.value(inputs)

        attn_score = tf.einsum("bhwc, bHWc->bhwHW", q, k) * scale
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height * width])

        attn_score = tf.nn.softmax(attn_score, -1)
        attn_score = tf.reshape(attn_score, [batch_size, height, width, height, width])

        proj = tf.einsum("bhwHW,bHWc->bhwc", attn_score, v)
        proj = self.proj(proj)
        return inputs + proj


def ResidualBlock(width, groups=8, activation_fn=keras.activations.swish):
    def apply(inputs):
        x, t = inputs
        input_width = x.shape[3]

        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(width, 
                                     kernel_size=1, 
                                     kernel_initializer=kernel_init(1.0)
                                    )(x)

        temb = activation_fn(t)
        temb = layers.Dense(width, 
                            kernel_initializer=kernel_init(1.0)
                           )(temb)[:, None, None, :]

        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)
        x = layers.Conv2D(width, 
                          kernel_size=3, 
                          padding="same", 
                          kernel_initializer=kernel_init(1.0)
                         )(x)

        x = layers.Add()([x, temb])
        x = layers.GroupNormalization(groups=groups)(x)
        x = activation_fn(x)

        x = layers.Conv2D(width, 
                          kernel_size=3, 
                          padding="same", kernel_initializer=kernel_init(0.0)
                         )(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownSample(width):
    def apply(x):
        x = layers.Conv2D(width, kernel_size=3, strides=2, padding="same", kernel_initializer=kernel_init(1.0),)(x)
        
        return x

    return apply


def UpSample(width, interpolation="nearest"):
    def apply(x):
        x = layers.UpSampling2D(size=2, interpolation=interpolation)(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same", kernel_initializer=kernel_init(1.0))(x)
        
        return x

    return apply


class TimeEmbedding(layers.Layer):
    """
    one time point to embedding vector with dim. R^1--> R^dim
    """
    def __init__(self, dim, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.half_dim = dim // 2
        self.emb = math.log(10000) / (self.half_dim - 1)
        self.emb = tf.exp(tf.range(self.half_dim, dtype=tf.float32) * -self.emb)

    def call(self, inputs):
        inputs = tf.cast(inputs, dtype=tf.float32)
        emb = inputs[:, None] * self.emb[None, :]
        emb = tf.concat([tf.sin(emb), tf.cos(emb)], axis=-1)
        
        return emb


def TimeMLP(units, activation_fn=keras.activations.swish):
    def apply(inputs):
        temb = layers.Dense(units, activation=activation_fn, kernel_initializer=kernel_init(1.0))(inputs)
        temb = layers.Dense(units, kernel_initializer=kernel_init(1.0))(temb)
        return temb

    return apply




def build_unet_model_c2_no_cross_attn(img_size_H,
                     img_size_W,
                     img_channels,
                     widths,
                     has_attention,
                     num_res_blocks=2,
                     norm_groups=8,
                     first_conv_channels=64,
                     interpolation="nearest",
                     activation_fn=keras.activations.swish,
                     encoder=None
                    ):
    """
    define U-Net model
    """
    # image_input and time_input
    image_input = layers.Input(shape=(img_size_H, img_size_W, img_channels), name="image_input")
    time_input = keras.Input(shape=(), dtype=tf.int64, name="time_input")
    image_input_past1 = layers.Input(shape=(img_size_H, img_size_W, img_channels), name="image_input_past1")
    image_input_past2 = layers.Input(shape=(img_size_H, img_size_W, img_channels), name="image_input_past2")

    # ================= image past embedding =================
    image_input_past_embed1 = encoder(image_input_past1)
    image_input_past_embed1 = layers.Conv2D(first_conv_channels,
                                             kernel_size=(3, 3),
                                             padding="same",
                                             kernel_initializer=kernel_init(1.0),
                                            )(image_input_past_embed1)
    print("image_input_past_embed1 shape:", image_input_past_embed1.shape)

    image_input_past_embed2 = encoder(image_input_past1)
    image_input_past_embed2 = layers.Conv2D(first_conv_channels,
                                             kernel_size=(3, 3),
                                             padding="same",
                                             kernel_initializer=kernel_init(1.0),
                                            )(image_input_past_embed2)
    print("image_input_past_embed2 shape:", image_input_past_embed2.shape)

    
    image_input_past_embed = layers.Concatenate(axis=-1)([image_input_past_embed1, image_input_past_embed2])
    image_input_past_embed = layers.Conv2D(first_conv_channels,
                                     kernel_size=(3, 3),
                                     padding="same",
                                     kernel_initializer=kernel_init(1.0),
                                    )(image_input_past_embed)
    print("image_input_past_embed shape:", image_input_past_embed.shape)


    
    # ================= image_embedding =================
    image_input_embed = layers.Conv2D(first_conv_channels,
                                      kernel_size=(3, 3),
                                      padding="same",
                                      kernel_initializer=kernel_init(1.0),
                                     )(image_input)
    

    # ================= image_embedding =================
    x = layers.Add()([image_input_embed, image_input_past_embed])

    
    # time_embedding
    temb = TimeEmbedding(dim=first_conv_channels * 4)(time_input)
    temb = TimeMLP(units=first_conv_channels * 4, activation_fn=activation_fn)(temb)
    print("x.shape:", x.shape, "temb.shape:", temb.shape)
    
    skips = [x]

    # DownBlock
    for i in range(len(widths)):
        for _ in range(num_res_blocks):
            x = ResidualBlock(widths[i], groups=norm_groups, activation_fn=activation_fn)([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)
            skips.append(x)

        if widths[i] != widths[-1]:
            x = DownSample(widths[i])(x)
            skips.append(x)

    # MiddleBlock
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)([x, temb])
    x = AttentionBlock(widths[-1], groups=norm_groups)(x)
    x = ResidualBlock(widths[-1], groups=norm_groups, activation_fn=activation_fn)([x, temb])

    # UpBlock
    for i in reversed(range(len(widths))):
        for _ in range(num_res_blocks + 1):
            x = layers.Concatenate(axis=-1)([x, skips.pop()])
            x = ResidualBlock(widths[i], groups=norm_groups, activation_fn=activation_fn)([x, temb])
            if has_attention[i]:
                x = AttentionBlock(widths[i], groups=norm_groups)(x)

        if i != 0:
            x = UpSample(widths[i], interpolation=interpolation)(x)

    # End block
    x = layers.GroupNormalization(groups=norm_groups)(x)
    x = activation_fn(x)
    x = layers.Conv2D(img_channels, (2, 2), padding="same", kernel_initializer=kernel_init(1.0))(x)
    
    return keras.Model([image_input, time_input,
                        image_input_past1, image_input_past2, 
                        # image_input_past3, image_input_past4
                       ], x, name="unet")

# %%
# Build the unet model
network = build_unet_model_c2_no_cross_attn(
    img_size_H=img_size_H,
    img_size_W=img_size_W,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    first_conv_channels=first_conv_channels,
    activation_fn=keras.activations.swish,
    encoder=pretrained_encoder,
)
# Out:
# image_input_past_embed1 shape: (None, 32, 64, 64)
# image_input_past_embed2 shape: (None, 32, 64, 64)
# image_input_past_embed shape: (None, 32, 64, 64)
# x.shape: (None, 32, 64, 64) temb.shape: (None, 256)

# %%
# network.summary()

# %% [markdown]
# ## Training
# **Note:** We are using mean squared error as the loss function which is aligned with
# the paper, and theoretically makes sense. In practice, though, it is also common to
# use mean absolute error or Huber loss as the loss function.

# %%
class DiffusionModel(keras.Model):
    def __init__(self, network, ema_network, timesteps, gdf_util, ema=0.999):
        super().__init__()
        self.network = network  # denoiser or noise predictor
        self.ema_network = ema_network
        self.timesteps = timesteps
        self.gdf_util = gdf_util
        self.ema = ema

    def train_step(self, data):
        # Unpack the data
        (images, image_input_past1, image_input_past2), y = data
        
        # 1. Get the batch size
        batch_size = tf.shape(images)[0]
        
        # 2. Sample timesteps uniformly
        t = tf.random.uniform(minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64)

        with tf.GradientTape() as tape:
            # 3. Sample random noise to be added to the images in the batch
            noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)
            print("noise.shape:", noise.shape)
            
            # 4. Diffuse the images with noise
            images_t = self.gdf_util.q_sample(images, t, noise)
            print("images_t.shape:", images_t.shape)
            
            # 5. Pass the diffused images and time steps to the network
            pred_noise = self.network([images_t, t, image_input_past1, image_input_past2], training=True)
            print("pred_noise.shape:", pred_noise.shape)
            
            # 6. Calculate the loss
            loss = self.loss(noise, pred_noise)

        # 7. Get the gradients
        gradients = tape.gradient(loss, self.network.trainable_weights)

        # 8. Update the weights of the network
        self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

        # 9. Updates the weight values for the network with EMA weights
        for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
            ema_weight.assign(self.ema * ema_weight + (1 - self.ema) * weight)

        # 10. Return loss values
        return {"loss": loss}

    
    def test_step(self, data):
        # Unpack the data
        (images, image_input_past1, image_input_past2), y = data

        # 1. Get the batch size
        batch_size = tf.shape(images)[0]
        
        # 2. Sample timesteps uniformly
        t = tf.random.uniform(minval=0, maxval=self.timesteps, shape=(batch_size,), dtype=tf.int64)

        # 3. Sample random noise to be added to the images in the batch
        noise = tf.random.normal(shape=tf.shape(images), dtype=images.dtype)
        
        # 4. Diffuse the images with noise
        images_t = self.gdf_util.q_sample(images, t, noise)
        
        # 5. Pass the diffused images and time steps to the network
        pred_noise = self.network([images_t, t, image_input_past1, image_input_past2], training=False)
        
        # 6. Calculate the loss
        loss = self.loss(noise, pred_noise)

        # 7. Return loss values
        return {"loss": loss}



# Build the unet model
network = build_unet_model_c2_no_cross_attn(
    img_size_H=img_size_H,
    img_size_W=img_size_W,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    first_conv_channels=first_conv_channels,
    activation_fn=keras.activations.swish,
    encoder=pretrained_encoder,
)

ema_network = build_unet_model_c2_no_cross_attn(
    img_size_H=img_size_H,
    img_size_W=img_size_W,
    img_channels=img_channels,
    widths=widths,
    has_attention=has_attention,
    num_res_blocks=num_res_blocks,
    norm_groups=norm_groups,
    first_conv_channels=first_conv_channels,
    activation_fn=keras.activations.swish,
    encoder=pretrained_encoder,
)
ema_network.set_weights(network.get_weights())  # Initially the weights are the same
# Out:
# image_input_past_embed1 shape: (None, 32, 64, 64)
# image_input_past_embed2 shape: (None, 32, 64, 64)
# image_input_past_embed shape: (None, 32, 64, 64)
# x.shape: (None, 32, 64, 64) temb.shape: (None, 256)
# image_input_past_embed1 shape: (None, 32, 64, 64)
# image_input_past_embed2 shape: (None, 32, 64, 64)
# image_input_past_embed shape: (None, 32, 64, 64)
# x.shape: (None, 32, 64, 64) temb.shape: (None, 256)

# %%
# ema_network.summary()

# %% [markdown]
# ### Training

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(((train_data_tf_norm_pred, 
                                                     train_data_tf_norm_past1, 
                                                     train_data_tf_norm_past2,
                                                    ), train_data_tf_norm_pred))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices(((val_data_tf_norm_pred, 
                                                   val_data_tf_norm_past1,
                                                   val_data_tf_norm_past2,
                                                  ), val_data_tf_norm_pred))
val_dataset = val_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
from loss.loss import lat_weighted_loss_mse_56deg

# %%
learning_rate = 2e-4
decay_steps = 10000
decay_rate = 0.95


# Get an instance of the Gaussian Diffusion utilities
gdf_util = GaussianDiffusion(timesteps=total_timesteps)

# Get the model
model = DiffusionModel(
    network=network,
    ema_network=ema_network,
    gdf_util=gdf_util,
    timesteps=total_timesteps,
)

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
                                                          decay_steps=decay_steps,
                                                          decay_rate=decay_rate
                                                         )

# Compile the model
model.compile(
              loss=keras.losses.MeanSquaredError(),
              # loss=lat_weighted_loss_mse_56deg,
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule)
             )

# Train the model
model.fit(train_dataset,
          validation_data=val_dataset,
          epochs=num_epochs,
          batch_size=batch_size
         )
# Out:
# Epoch 1/800
# noise.shape: (None, 32, 64, 5)
# images_t.shape: (None, 32, 64, 5)
# pred_noise.shape: (None, 32, 64, 5)
# noise.shape: (None, 32, 64, 5)
# images_t.shape: (None, 32, 64, 5)
# pred_noise.shape: (None, 32, 64, 5)
# 2024-07-25 00:40:00.862512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8907
# 2024-07-25 00:40:00.917034: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-25 00:40:01.988228: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-07-25 00:40:04.617961: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x8bcca90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-25 00:40:04.617988: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# 2024-07-25 00:40:04.623086: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-25 00:40:04.688526: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-25 00:40:04.703696: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 69/69 [==============================] - 114s 722ms/step - loss: 0.6525 - val_loss: 0.1301
# Epoch 2/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0787 - val_loss: 0.0503
# Epoch 3/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0493 - val_loss: 0.0466
# Epoch 4/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0358 - val_loss: 0.0290
# Epoch 5/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0293 - val_loss: 0.0256
# Epoch 6/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0245 - val_loss: 0.0228
# Epoch 7/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0206 - val_loss: 0.0223
# Epoch 8/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0190 - val_loss: 0.0204
# Epoch 9/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0174 - val_loss: 0.0185
# Epoch 10/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0171 - val_loss: 0.0236
# Epoch 11/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0154 - val_loss: 0.0130
# Epoch 12/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0147 - val_loss: 0.0135
# Epoch 13/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0141 - val_loss: 0.0159
# Epoch 14/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0126 - val_loss: 0.0106
# Epoch 15/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0133 - val_loss: 0.0176
# Epoch 16/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0128 - val_loss: 0.0085
# Epoch 17/800
# 69/69 [==============================] - 39s 573ms/step - loss: 0.0124 - val_loss: 0.0098
# Epoch 18/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0121 - val_loss: 0.0068
# Epoch 19/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0117 - val_loss: 0.0066
# Epoch 20/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 21/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0116 - val_loss: 0.0088
# Epoch 22/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0105 - val_loss: 0.0117
# Epoch 23/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 24/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0110 - val_loss: 0.0141
# Epoch 25/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0110 - val_loss: 0.0155
# Epoch 26/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0102 - val_loss: 0.0088
# Epoch 27/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0105 - val_loss: 0.0119
# Epoch 28/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0108 - val_loss: 0.0084
# Epoch 29/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0106 - val_loss: 0.0173
# Epoch 30/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0092 - val_loss: 0.0136
# Epoch 31/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0099 - val_loss: 0.0081
# Epoch 32/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0095 - val_loss: 0.0122
# Epoch 33/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 34/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0093 - val_loss: 0.0042
# Epoch 35/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0093 - val_loss: 0.0106
# Epoch 36/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 37/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0101 - val_loss: 0.0117
# Epoch 38/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0095 - val_loss: 0.0150
# Epoch 39/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0090 - val_loss: 0.0108
# Epoch 40/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0093 - val_loss: 0.0060
# Epoch 41/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0086 - val_loss: 0.0129
# Epoch 42/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0088 - val_loss: 0.0094
# Epoch 43/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0086 - val_loss: 0.0063
# Epoch 44/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 45/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0081 - val_loss: 0.0113
# Epoch 46/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 47/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 48/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0086 - val_loss: 0.0112
# Epoch 49/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0083 - val_loss: 0.0077
# Epoch 50/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 51/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0083 - val_loss: 0.0036
# Epoch 52/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0079 - val_loss: 0.0052
# Epoch 53/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0076 - val_loss: 0.0127
# Epoch 54/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0079 - val_loss: 0.0113
# Epoch 55/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 56/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 57/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0079 - val_loss: 0.0052
# Epoch 58/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0082 - val_loss: 0.0077
# Epoch 59/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 60/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 61/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0076 - val_loss: 0.0052
# Epoch 62/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 63/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 64/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0079 - val_loss: 0.0144
# Epoch 65/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0070 - val_loss: 0.0109
# Epoch 66/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 67/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 68/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0117
# Epoch 69/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0089
# Epoch 70/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0073 - val_loss: 0.0040
# Epoch 71/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0076 - val_loss: 0.0025
# Epoch 72/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 73/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 74/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 75/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0065 - val_loss: 0.0091
# Epoch 76/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 77/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0069 - val_loss: 0.0117
# Epoch 78/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0074 - val_loss: 0.0112
# Epoch 79/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0070 - val_loss: 0.0082
# Epoch 80/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 81/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 82/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0066 - val_loss: 0.0051
# Epoch 83/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0062 - val_loss: 0.0092
# Epoch 84/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0069 - val_loss: 0.0084
# Epoch 85/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0070 - val_loss: 0.0173
# Epoch 86/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 87/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0070 - val_loss: 0.0034
# Epoch 88/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0067 - val_loss: 0.0042
# Epoch 89/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 90/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0072 - val_loss: 0.0034
# Epoch 91/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 92/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0071 - val_loss: 0.0031
# Epoch 93/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0072 - val_loss: 0.0056
# Epoch 94/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0072 - val_loss: 0.0091
# Epoch 95/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 96/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 97/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0067 - val_loss: 0.0094
# Epoch 98/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 99/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0080
# Epoch 100/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 101/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 102/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0061 - val_loss: 0.0112
# Epoch 103/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0065 - val_loss: 0.0106
# Epoch 104/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 105/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0061 - val_loss: 0.0109
# Epoch 106/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 107/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0064 - val_loss: 0.0031
# Epoch 108/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0060 - val_loss: 0.0087
# Epoch 109/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 110/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 111/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0128
# Epoch 112/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 113/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0063 - val_loss: 0.0105
# Epoch 114/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0064 - val_loss: 0.0045
# Epoch 115/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 116/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 117/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 118/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0084
# Epoch 119/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0064 - val_loss: 0.0085
# Epoch 120/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0059 - val_loss: 0.0120
# Epoch 121/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 122/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 123/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 124/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 125/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 126/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 127/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0088
# Epoch 128/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0060 - val_loss: 0.0092
# Epoch 129/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0080
# Epoch 130/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0060 - val_loss: 0.0089
# Epoch 131/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 132/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 133/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 134/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 135/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 136/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 137/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0061 - val_loss: 0.0033
# Epoch 138/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 139/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0092
# Epoch 140/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0054 - val_loss: 0.0108
# Epoch 141/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 142/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 143/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 144/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 145/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0056 - val_loss: 0.0069
# Epoch 146/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 147/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0065
# Epoch 148/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 149/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 150/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0094
# Epoch 151/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 152/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0056 - val_loss: 0.0083
# Epoch 153/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 154/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0070
# Epoch 155/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 156/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0061
# Epoch 157/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0080
# Epoch 158/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 159/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 160/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 161/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 162/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 163/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 164/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 165/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 166/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0089
# Epoch 167/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 168/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 169/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0092
# Epoch 170/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 171/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 172/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0090
# Epoch 173/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0087
# Epoch 174/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 175/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 176/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0108
# Epoch 177/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 178/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0062 - val_loss: 0.0094
# Epoch 179/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 180/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 181/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 182/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 183/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 184/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 185/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0054 - val_loss: 0.0076
# Epoch 186/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0055 - val_loss: 0.0074
# Epoch 187/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 188/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 189/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0102
# Epoch 190/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 191/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 192/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 193/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0063
# Epoch 194/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 195/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0081
# Epoch 196/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0069
# Epoch 197/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0050 - val_loss: 0.0057
# Epoch 198/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 199/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0057 - val_loss: 0.0088
# Epoch 200/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 201/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0023
# Epoch 202/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 203/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 204/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0081
# Epoch 205/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0057 - val_loss: 0.0059
# Epoch 206/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0048 - val_loss: 0.0078
# Epoch 207/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0050 - val_loss: 0.0116
# Epoch 208/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0078
# Epoch 209/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0051 - val_loss: 0.0095
# Epoch 210/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 211/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0044
# Epoch 212/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 213/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0048 - val_loss: 0.0079
# Epoch 214/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 215/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0093
# Epoch 216/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 217/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 218/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0082
# Epoch 219/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 220/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0051 - val_loss: 0.0075
# Epoch 221/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 222/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 223/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 224/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0082
# Epoch 225/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0076
# Epoch 226/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 227/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0051 - val_loss: 0.0084
# Epoch 228/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 229/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 230/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0069
# Epoch 231/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 232/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 233/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 234/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0096
# Epoch 235/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 236/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 237/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 238/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 239/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 240/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 241/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 242/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0045 - val_loss: 0.0063
# Epoch 243/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 244/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 245/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 246/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 247/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 248/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 249/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0048 - val_loss: 0.0073
# Epoch 250/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 251/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 252/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 253/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0053 - val_loss: 0.0117
# Epoch 254/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0047 - val_loss: 0.0025
# Epoch 255/800
# 69/69 [==============================] - 39s 569ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 256/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 257/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 258/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 259/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 260/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 261/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 262/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 263/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0027
# Epoch 264/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0088
# Epoch 265/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 266/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0045 - val_loss: 0.0078
# Epoch 267/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 268/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 269/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 270/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 271/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 272/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 273/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 274/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 275/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0082
# Epoch 276/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 277/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0073
# Epoch 278/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 279/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 280/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 281/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0069
# Epoch 282/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 283/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 284/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 285/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 286/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0086
# Epoch 287/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0072
# Epoch 288/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0049 - val_loss: 0.0070
# Epoch 289/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 290/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 291/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 292/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 293/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 294/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 295/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 296/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 297/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 298/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0088
# Epoch 299/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 300/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0077
# Epoch 301/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0071
# Epoch 302/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 303/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0029
# Epoch 304/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 305/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0059
# Epoch 306/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 307/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 308/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 309/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0058
# Epoch 310/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0103
# Epoch 311/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 312/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 313/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0083
# Epoch 314/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 315/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0090
# Epoch 316/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 317/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 318/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0041 - val_loss: 0.0076
# Epoch 319/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 320/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0053
# Epoch 321/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0047 - val_loss: 0.0065
# Epoch 322/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0045 - val_loss: 0.0079
# Epoch 323/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 324/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0020
# Epoch 325/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0025
# Epoch 326/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0049 - val_loss: 0.0105
# Epoch 327/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 328/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 329/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 330/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 331/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 332/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 333/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0060
# Epoch 334/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0107
# Epoch 335/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 336/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0093
# Epoch 337/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0080
# Epoch 338/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 339/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 340/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0070
# Epoch 341/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 342/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0068
# Epoch 343/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 344/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0130
# Epoch 345/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0100
# Epoch 346/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 347/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 348/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 349/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 350/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 351/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 352/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0105
# Epoch 353/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 354/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 355/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 356/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 357/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 358/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 359/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 360/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 361/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 362/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 363/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 364/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 365/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 366/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 367/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0051
# Epoch 368/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 369/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0041 - val_loss: 0.0051
# Epoch 370/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0048 - val_loss: 0.0126
# Epoch 371/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 372/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 373/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 374/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0045 - val_loss: 0.0084
# Epoch 375/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 376/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 377/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 378/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 379/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 380/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 381/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 382/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 383/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 384/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0030
# Epoch 385/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 386/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 387/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 388/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 389/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 390/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 391/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 392/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0071
# Epoch 393/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 394/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 395/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 396/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0042 - val_loss: 0.0088
# Epoch 397/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0066
# Epoch 398/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 399/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 400/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 401/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 402/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 403/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 404/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 405/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 406/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 407/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 408/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 409/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 410/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0066
# Epoch 411/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 412/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 413/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 414/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 415/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 416/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 417/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 418/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 419/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 420/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 421/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0066
# Epoch 422/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 423/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 424/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 425/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0064
# Epoch 426/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 427/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 428/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 429/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 430/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0044 - val_loss: 0.0082
# Epoch 431/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 432/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0054
# Epoch 433/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0073
# Epoch 434/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 435/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 436/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 437/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 438/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 439/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0039 - val_loss: 0.0103
# Epoch 440/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 441/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0086
# Epoch 442/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 443/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 444/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 445/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0042 - val_loss: 0.0031
# Epoch 446/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 447/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0044 - val_loss: 0.0022
# Epoch 448/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 449/800
# ...
# Epoch 648/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 649/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 650/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 651/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0035 - val_loss: 0.0073
# Epoch 652/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 653/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 654/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 655/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 656/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 657/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0033 - val_loss: 0.0112
# Epoch 658/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0036 - val_loss: 0.0082
# Epoch 659/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0050
# Epoch 660/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0056
# Epoch 661/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 662/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0086
# Epoch 663/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 664/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0053
# Epoch 665/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 666/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0101
# Epoch 667/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 668/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 669/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0037 - val_loss: 0.0072
# Epoch 670/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0072
# Epoch 671/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 672/800
# 69/69 [==============================] - 40s 575ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 673/800
# 69/69 [==============================] - 40s 573ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 674/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 675/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 676/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 677/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 678/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 679/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 680/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 681/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 682/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 683/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 684/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0050
# Epoch 685/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 686/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 687/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0075
# Epoch 688/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 689/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 690/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0067
# Epoch 691/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0033 - val_loss: 0.0099
# Epoch 692/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 693/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 694/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0077
# Epoch 695/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0068
# Epoch 696/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 697/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0065
# Epoch 698/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0034 - val_loss: 0.0065
# Epoch 699/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 700/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0039 - val_loss: 0.0097
# Epoch 701/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 702/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0050
# Epoch 703/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 704/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0060
# Epoch 705/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0071
# Epoch 706/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0037 - val_loss: 0.0099
# Epoch 707/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 708/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 709/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 710/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0090
# Epoch 711/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 712/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 713/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 714/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 715/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 716/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 717/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0037 - val_loss: 0.0076
# Epoch 718/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 719/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 720/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0052
# Epoch 721/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0061
# Epoch 722/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0054
# Epoch 723/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0047
# Epoch 724/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0071
# Epoch 725/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 726/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 727/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0086
# Epoch 728/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 729/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 730/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 731/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0095
# Epoch 732/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 733/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 734/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0032 - val_loss: 0.0065
# Epoch 735/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0081
# Epoch 736/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0038 - val_loss: 0.0091
# Epoch 737/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 738/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 739/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 740/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 741/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0052
# Epoch 742/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 743/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 744/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0064
# Epoch 745/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 746/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0052
# Epoch 747/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 748/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0077
# Epoch 749/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 750/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 751/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0078
# Epoch 752/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 753/800
# 69/69 [==============================] - 40s 574ms/step - loss: 0.0035 - val_loss: 0.0052
# Epoch 754/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 755/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 756/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 757/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 758/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0069
# Epoch 759/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0058
# Epoch 760/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 761/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0036 - val_loss: 0.0090
# Epoch 762/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0060
# Epoch 763/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 764/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0048
# Epoch 765/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0030 - val_loss: 0.0106
# Epoch 766/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 767/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 768/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 769/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 770/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0076
# Epoch 771/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 772/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0035 - val_loss: 0.0073
# Epoch 773/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0029 - val_loss: 0.0111
# Epoch 774/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 775/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0036 - val_loss: 0.0072
# Epoch 776/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 777/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0109
# Epoch 778/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0034 - val_loss: 0.0075
# Epoch 779/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0030 - val_loss: 0.0099
# Epoch 780/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0033 - val_loss: 0.0069
# Epoch 781/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0038 - val_loss: 0.0134
# Epoch 782/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 783/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 784/800
# 69/69 [==============================] - 39s 572ms/step - loss: 0.0031 - val_loss: 0.0068
# Epoch 785/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 786/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 787/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0039 - val_loss: 0.0062
# Epoch 788/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 789/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0058
# Epoch 790/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 791/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 792/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0035 - val_loss: 0.0056
# Epoch 793/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 794/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 795/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0086
# Epoch 796/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 797/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0030 - val_loss: 0.0110
# Epoch 798/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0037 - val_loss: 0.0087
# Epoch 799/800
# 69/69 [==============================] - 39s 570ms/step - loss: 0.0036 - val_loss: 0.0050
# Epoch 800/800
# 69/69 [==============================] - 39s 571ms/step - loss: 0.0033 - val_loss: 0.0076

# %%
# Save weights
model.save_weights('../checkpoints/ddpm_weather_56c2_56_5var_cp3_no_cross_attn')

# %%
# Restore weights
model.load_weights('../checkpoints/ddpm_weather_56c2_56_5var_cp3_no_cross_attn')
